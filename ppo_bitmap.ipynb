# %% [markdown]
# # PPO Algorithm
#
# This code performs PPO on the Patrolling Zoo environment.

# %%
# %reload_ext autoreload
# %autoreload 2

import torch
from patrolling_zoo.patrolling_zoo_v0 import parallel_env, PatrolGraph
from algorithm.ppo_bitmap import PPO

# set process priority low
import psutil
import os
if os.name == 'nt':
    psutil.Process(os.getpid()).nice(psutil.BELOW_NORMAL_PRIORITY_CLASS)
else:
    psutil.Process(os.getpid()).nice(10)

# %% [markdown]
# # Configuration

# %%
MAX_CYCLES = 50

""" ENV SETUP """
patrolGraph = PatrolGraph("patrolling_zoo/env/4nodes.graph")
env = parallel_env(patrolGraph, 1,
    require_explicit_visit = True,
    speed = 5,
    alpha = 10,
    max_cycles = MAX_CYCLES,
    observation_mode = "bitmap"
)

"""ALGO PARAMS"""
algo = PPO(
    env = env,
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu"),
    ent_coef = 0.1,
    vf_coef = 0.1,
    clip_coef = 0.1,
    gamma = 0.99,
    lr = 1e-4,
    stack_size = 4,
    batch_size = 1,
    frame_size = (len(parallel_env.OBSERVATION_CHANNELS), env.pg.widthPixels, env.pg.heightPixels),
    max_cycles = MAX_CYCLES,
    total_episodes = 20
)

# %%
# Use matplotlib to visualize the observation. The observation is a bitmap of the environment.
env.reset()
env.step([0, 0])
obs = env.state()
print(obs.shape)

# print(obs)
import matplotlib.pyplot as plt
plt.imshow(obs)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (100, 100, 3)

# %%
# raise Exception("Stop here")

# %% [markdown]
# # Training

# %%
stats = algo.train(seed=42)
# Out:
# obs.shape (100, 100, 3)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 stats = algo.train(seed=42)
#
# File c:\Users\Anthony\Development\patrolling_zoo2\algorithm\ppo_bitmap.py:107, in PPO.train(self, seed)
#     105 rb_terms[step] = self.learner.batchify(terms, self.device)
#     106 rb_actions[step] = actions
# --> 107 rb_logprobs[step] = logprobs
#     108 rb_values[step] = values.flatten()
#     110 # compute episodic return
#
# RuntimeError: The expanded size of the tensor (1) must match the existing size (128) at non-singleton dimension 0.  Target sizes: [1].  Tensor sizes: [128]

# %%
algo.save()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(2, 2, sharex=True, figsize=(12, 6))
fig.suptitle("Training Statistics per Episode")

ax[0, 0].set_title("Reward vs. Episode")
ax[0, 0].plot(stats["episodic_return"])

ax[1, 0].set_title("Iterations vs. Episode")
ax[1, 0].plot(stats["episodic_length"])

plt.show()


fig, ax = plt.subplots(4, 2, sharex=True, figsize=(12, 10))
fig.suptitle("Training Statistics per Iteration")

ax[0, 1].set_title("Value Loss vs. Iteration")
ax[0, 1].plot(stats["value_loss"], label="value_loss")
# ax[0, 1].legend()

ax[1, 0].set_title("Policy Loss vs. Iteration")
ax[1, 0].plot(stats["policy_loss"], label="policy_loss")
# ax[1, 0].legend()

ax[1, 1].set_title("Entropy Loss vs. Iteration")
ax[1, 1].plot(stats["entropy_loss"], label="entropy_loss")
# ax[1, 1].legend()

ax[2, 0].set_title("Total Loss vs. Iteration")
ax[2, 0].plot(stats["total_loss"], label="total_loss")
# ax[2, 0].legend()

ax[2, 1].set_title("Approx. KL-Divergence vs. Iteration")
ax[2, 1].plot(stats["approx_kl"])

ax[3, 0].set_title("Clip Fraction vs. Iteration")
ax[3, 0].plot(stats["clip_frac"])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 7
#       4 fig.suptitle("Training Statistics per Episode")
#       6 ax[0, 0].set_title("Reward vs. Episode")
# ----> 7 ax[0, 0].plot(stats["episodic_return"])
#       9 ax[1, 0].set_title("Iterations vs. Episode")
#      10 ax[1, 0].plot(stats["episodic_length"])
#
# NameError: name 'stats' is not defined

# %% [markdown]
# # Evaluation

# %%
algo.evaluate(render=True, max_cycles=100, seed=42)
# Out:
# obs.shape (1, 100, 50, 3)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[109], line 1
# ----> 1 algo.evaluate(render=True, max_cycles=100, seed=42)
#
# File c:\Users\Anthony\Development\patrolling_zoo\algorithm\ppo_bitmap.py:236, in PPO.evaluate(self, render, max_cycles, max_episodes, seed)
#     234 truncs = [False]
#     235 while not any(terms) and not any(truncs):
# --> 236     actions, logprobs, _, values = self.learner.get_action_and_value(obs)
#     237     obs, rewards, terms, truncs, infos = self.env.step(self.learner.unbatchify(actions, self.env))
#     238     obs = self.learner.batchify_obs(self.env.observation_space(self.env.possible_agents[0]), obs, self.device)
#
# File c:\Users\Anthony\Development\patrolling_zoo\algorithm\ppo_bitmap.py:281, in PPONetwork.get_action_and_value(self, x, action)
#     280 def get_action_and_value(self, x, action=None):
# --> 281     hidden = self.network(x / 255.0)
#     282     logits = self.actor(hidden)
#     283     logits_split = torch.split(logits, split_size_or_sections=1, dim=0)
#
# File c:\Users\Anthony\miniconda3\envs\patrolling_zoo\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\Anthony\miniconda3\envs\patrolling_zoo\lib\site-packages\torch\nn\modules\container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File c:\Users\Anthony\miniconda3\envs\patrolling_zoo\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\Anthony\miniconda3\envs\patrolling_zoo\lib\site-packages\torch\nn\modules\linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (1x9216 and 8192x512)
