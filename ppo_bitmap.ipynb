# %% [markdown]
# # PPO Algorithm
#
# This code performs PPO on the Patrolling Zoo environment.

# %%
# %reload_ext autoreload
# %autoreload 2

import torch
from patrolling_zoo.patrolling_zoo_v0 import parallel_env, PatrolGraph
from algorithm.ppo_bitmap import PPO

# set process priority low
import psutil
import os
if os.name == 'nt':
    psutil.Process(os.getpid()).nice(psutil.BELOW_NORMAL_PRIORITY_CLASS)
else:
    psutil.Process(os.getpid()).nice(10)

# %% [markdown]
# # Configuration

# %%
MAX_CYCLES = 50

""" ENV SETUP """
patrolGraph = PatrolGraph("patrolling_zoo/env/4nodes.graph")
env = parallel_env(patrolGraph, 2,
    require_explicit_visit = True,
    speed = 5,
    alpha = 10,
    max_cycles = MAX_CYCLES,
    observation_mode = "bitmap"
)

"""ALGO PARAMS"""
algo = PPO(
    env = env,
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu"),
    ent_coef = 0.1,
    vf_coef = 0.1,
    clip_coef = 0.1,
    gamma = 0.99,
    lr = 1e-4,
    stack_size = 4,
    batch_size = 1,
    frame_size = (env.pg.widthPixels, env.pg.heightPixels, len(parallel_env.OBSERVATION_CHANNELS)),
    max_cycles = MAX_CYCLES,
    total_episodes = 2
)

# %% [markdown]
# # Training

# %%
stats = algo.train(seed=42)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 stats = algo.train(seed=42)
#
# File c:\Users\Anthony\Development\patrolling_zoo\algorithm\ppo_bitmap.py:79, in PPO.train(self, seed)
#      75 for episode in range(self.total_episodes):
#      76     # collect an episode
#      77     with torch.no_grad():
#      78         # collect observations and convert to batch of torch tensors
# ---> 79         next_obs, info = self.env.reset(seed=seed)
#      81         # reset the episodic return
#      82         total_episodic_return = 0
#
# File c:\Users\Anthony\Development\patrolling_zoo\patrolling_zoo\env\patrolling_zoo.py:165, in parallel_env.reset(self, seed, options)
#     162 self.step_count = 0
#     163 self.dones = dict.fromkeys(self.agents, False)
# --> 165 observation = {agent: self.observe(agent) for agent in self.agents}
#     166 info = {}
#     167 return observation, info
#
# File c:\Users\Anthony\Development\patrolling_zoo\patrolling_zoo\env\patrolling_zoo.py:165, in <dictcomp>(.0)
#     162 self.step_count = 0
#     163 self.dones = dict.fromkeys(self.agents, False)
# --> 165 observation = {agent: self.observe(agent) for agent in self.agents}
#     166 info = {}
#     167 return observation, info
#
# File c:\Users\Anthony\Development\patrolling_zoo\patrolling_zoo\env\patrolling_zoo.py:278, in parallel_env.observe(self, agent)
#     265                 obs[int(pos1[0] + (pos2[0] - pos1[0]) * i / dist), int(pos1[1] + (pos2[1] - pos1[1]) * i / dist), self.OBSERVATION_CHANNELS.OBSTACLE] = 0.0
#     267     # Fancier edge drawing.
#     268     # for edge in self.pg.graph.edges:
#     269     #     pos1 = np.array(self.pg.getNodePosition(edge[0]))
#    (...)
#     275     #             if d < 5.0:
#     276     #                 obs[i, j, self.OBSERVATION_CHANNELS.OBSTACLE] = 0.0
# --> 278 elif self.observation_mode == "vector":
#     279     # Calculate the shortest path distances from each agent to each node.
#     280     vertexDistances = {}
#     281     for a in agents:
#
# AttributeError: 'parallel_env' object has no attribute 'observation_mode'

# %%
algo.save()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(2, 2, sharex=True, figsize=(12, 6))
fig.suptitle("Training Statistics per Episode")

ax[0, 0].set_title("Reward vs. Episode")
ax[0, 0].plot(stats["episodic_return"])

ax[1, 0].set_title("Iterations vs. Episode")
ax[1, 0].plot(stats["episodic_length"])

plt.show()


fig, ax = plt.subplots(4, 2, sharex=True, figsize=(12, 10))
fig.suptitle("Training Statistics per Iteration")

ax[0, 1].set_title("Value Loss vs. Iteration")
ax[0, 1].plot(stats["value_loss"], label="value_loss")
# ax[0, 1].legend()

ax[1, 0].set_title("Policy Loss vs. Iteration")
ax[1, 0].plot(stats["policy_loss"], label="policy_loss")
# ax[1, 0].legend()

ax[1, 1].set_title("Entropy Loss vs. Iteration")
ax[1, 1].plot(stats["entropy_loss"], label="entropy_loss")
# ax[1, 1].legend()

ax[2, 0].set_title("Total Loss vs. Iteration")
ax[2, 0].plot(stats["total_loss"], label="total_loss")
# ax[2, 0].legend()

ax[2, 1].set_title("Approx. KL-Divergence vs. Iteration")
ax[2, 1].plot(stats["approx_kl"])

ax[3, 0].set_title("Clip Fraction vs. Iteration")
ax[3, 0].plot(stats["clip_frac"])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 7
#       4 fig.suptitle("Training Statistics per Episode")
#       6 ax[0, 0].set_title("Reward vs. Episode")
# ----> 7 ax[0, 0].plot(stats["episodic_return"])
#       9 ax[1, 0].set_title("Iterations vs. Episode")
#      10 ax[1, 0].plot(stats["episodic_length"])
#
# NameError: name 'stats' is not defined

# %% [markdown]
# # Evaluation

# %%
algo.evaluate(render=True, max_cycles=100, seed=42)
